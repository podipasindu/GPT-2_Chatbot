# %% [markdown]
# # **This code is an implementation of a chatbot using the GPT-2 language model from Hugging Face's Transformers library.**
# <br>
# Reference: https://huggingface.co/transformers/v2.2.0/pretrained_models.html

# %%
# @title
# !pip install transformers[torch] -U
# !pip install torch
# !pip install -U PyPDF2
# !pip install python-docx
# Out:
# Requirement already satisfied: transformers[torch] in c:\users\pasindu\anaconda3\lib\site-packages (4.41.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (2021.4.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (20.9)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (5.4.1)
# Requirement already satisfied: requests in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (1.22.4)
# Requirement already satisfied: filelock in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (3.0.12)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (0.23.3)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (0.31.0)
# Requirement already satisfied: torch in c:\users\pasindu\anaconda3\lib\site-packages (from transformers[torch]) (2.3.1)
# Requirement already satisfied: psutil in c:\users\pasindu\anaconda3\lib\site-packages (from accelerate>=0.21.0->transformers[torch]) (5.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pasindu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pasindu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2024.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\pasindu\anaconda3\lib\site-packages (from packaging>=20.0->transformers[torch]) (2.4.7)
# Requirement already satisfied: sympy in c:\users\pasindu\anaconda3\lib\site-packages (from torch->transformers[torch]) (1.8)
# Requirement already satisfied: networkx in c:\users\pasindu\anaconda3\lib\site-packages (from torch->transformers[torch]) (2.5)
# Requirement already satisfied: jinja2 in c:\users\pasindu\anaconda3\lib\site-packages (from torch->transformers[torch]) (2.11.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\pasindu\anaconda3\lib\site-packages (from torch->transformers[torch]) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\pasindu\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->transformers[torch]) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\pasindu\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->transformers[torch]) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pasindu\anaconda3\lib\site-packages (from jinja2->torch->transformers[torch]) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\pasindu\anaconda3\lib\site-packages (from networkx->torch->transformers[torch]) (5.0.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pasindu\anaconda3\lib\site-packages (from requests->transformers[torch]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pasindu\anaconda3\lib\site-packages (from requests->transformers[torch]) (2020.12.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pasindu\anaconda3\lib\site-packages (from requests->transformers[torch]) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pasindu\anaconda3\lib\site-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pasindu\anaconda3\lib\site-packages (from sympy->torch->transformers[torch]) (1.2.1)
# Requirement already satisfied: torch in c:\users\pasindu\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: networkx in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (2.5)
# Requirement already satisfied: fsspec in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: jinja2 in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: filelock in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (3.0.12)
# Requirement already satisfied: sympy in c:\users\pasindu\anaconda3\lib\site-packages (from torch) (1.8)
# Requirement already satisfied: tbb==2021.* in c:\users\pasindu\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\pasindu\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pasindu\anaconda3\lib\site-packages (from jinja2->torch) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\pasindu\anaconda3\lib\site-packages (from networkx->torch) (5.0.6)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pasindu\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Requirement already satisfied: PyPDF2 in c:\users\pasindu\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\pasindu\anaconda3\lib\site-packages (from PyPDF2) (4.12.2)
# Requirement already satisfied: python-docx in c:\users\pasindu\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\pasindu\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\pasindu\anaconda3\lib\site-packages (from python-docx) (4.6.3)

# %%
import os
import re
from PyPDF2 import PdfReader
import docx
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# %% [markdown]
# Required functions to read text from various files located in a directory. Files can be a mix of pdf, docx, or txt.

# %%
# Functions to read different file types
def read_pdf(file_path):
    with open(file_path, "rb") as file:
        pdf_reader = PdfReader(file)
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            text += pdf_reader.pages[page_num].extract_text()
    return text

def read_word(file_path):
    doc = docx.Document(file_path)
    text = ""
    for paragraph in doc.paragraphs:
        text += paragraph.text + "\n"
    return text

def read_txt(file_path):
    with open(file_path, "r") as file:
        text = file.read()
    return text

def read_documents_from_directory(directory):
    combined_text = ""
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if filename.endswith(".pdf"):
            combined_text += read_pdf(file_path)
        elif filename.endswith(".docx"):
            combined_text += read_word(file_path)
        elif filename.endswith(".txt"):
            combined_text += read_txt(file_path)
    return combined_text

# %% [markdown]
# The train_chatbot function uses the combined text data to train a GPT-2 model using the provided training arguments. The resulting trained model and tokenizer are then saved to a specified output directory.

# %%
def train_chatbot(directory, model_output_path, train_fraction=0.8):
    # Read documents from the directory
    combined_text = read_documents_from_directory(directory)
    combined_text = re.sub(r'\n+', '\n', combined_text).strip()  # Remove excess newline characters

    # Split the text into training and validation sets
    split_index = int(train_fraction * len(combined_text))
    train_text = combined_text[:split_index]
    val_text = combined_text[split_index:]

    # Save the training and validation data as text files
    with open("train.txt", "w") as f:
        f.write(train_text)
    with open("val.txt", "w") as f:
        f.write(val_text)

    # Set up the tokenizer and model
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")  #also try gpt2, gpt2-large and gpt2-medium, also gpt2-xl
    model = GPT2LMHeadModel.from_pretrained("gpt2-large")  #also try gpt2, gpt2-large and gpt2-medium, also gpt2-xl

    # Prepare the dataset
    train_dataset = TextDataset(tokenizer=tokenizer, file_path="train.txt", block_size=128)
    val_dataset = TextDataset(tokenizer=tokenizer, file_path="val.txt", block_size=128)
    data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

    # Set up the training arguments
    training_args = TrainingArguments(
        output_dir=model_output_path,
        overwrite_output_dir=True,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        num_train_epochs=100,
        save_steps=10_000,
        save_total_limit=2,
        logging_dir='./logs',
    )

    # Train the model
    trainer = Trainer(
        model=model,
        args=training_args,
        data_collator=data_collator,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
    )

    trainer.train()
    trainer.save_model(model_output_path)

    # Save the tokenizer
    tokenizer.save_pretrained(model_output_path)

# %% [markdown]
# The generate_response function takes a trained model, tokenizer, and a prompt string as input and generates a response using the GPT-2 model.

# %%
def generate_response(model, tokenizer, prompt, max_length=100):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # Create the attention mask and pad token id
    attention_mask = torch.ones_like(input_ids)
    pad_token_id = tokenizer.eos_token_id

    output = model.generate(
        input_ids,
        max_length=max_length,
        num_return_sequences=1,
        attention_mask=attention_mask,
        pad_token_id=pad_token_id
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %% [markdown]
# The main function is the entry point for the program. It specifies the path to the directory containing the training data and the path to the output directory for the trained model and tokenizer. It then trains the chatbot using the train_chatbot function and generates a response to a specified prompt using the generate_response function.

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

def train_chatbot(directory, model_output_path):
    # Add your training code here
    # For now, let's just save an empty model and tokenizer to the path
    model = GPT2LMHeadModel.from_pretrained('gpt2')
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model.save_pretrained(model_output_path)
    tokenizer.save_pretrained(model_output_path)

def generate_response(model, tokenizer, prompt):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    output = model.generate(input_ids, max_length=100, num_return_sequences=1)
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

def main():
    # Replace with the path to your directory containing the files
    directory = "C:\\Users\\Pasindu\\chatNew\\training_data"  
    # Replace with the path to your model output directory
    model_output_path = "C:\\Users\\Pasindu\\chatNew\\model_output"

    # Train the chatbot
    train_chatbot(directory, model_output_path)

    # Load the fine-tuned model and tokenizer
    model = GPT2LMHeadModel.from_pretrained(model_output_path)
    tokenizer = GPT2Tokenizer.from_pretrained(model_output_path)


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Now, let us test the model.
# <p>
# Use the following code if you are only performing inference (generating text). This can be placed in a separate notebook.

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
def generate_response(model, tokenizer, prompt, max_length=250):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # Create the attention mask and pad token id
    attention_mask = torch.ones_like(input_ids)
    pad_token_id = tokenizer.eos_token_id

    output = model.generate(
        input_ids,
        max_length=max_length,
        num_return_sequences=1,
        attention_mask=attention_mask,
        pad_token_id=pad_token_id
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
model_path = "C:\\Users\\Pasindu\\chatNew\\model_output"
# Load the fine-tuned model and tokenizer
my_chat_model = GPT2LMHeadModel.from_pretrained(model_path)
my_chat_tokenizer = GPT2Tokenizer.from_pretrained(model_path)

# %% [markdown]
# In the case of the GPT-2 tokenizer, the model uses a byte-pair encoding (BPE) algorithm, which tokenizes text into subword units. As a result, one word might be represented by multiple tokens.
#
# For example, if you set max_length to 50, the generated response will be limited to 50 tokens, which could be fewer than 50 words, depending on the text.

# %%
prompt = "What is the mitosis?"
response = generate_response(my_chat_model, my_chat_tokenizer, prompt, max_length=150)
print("Generated response:", response)
# Out:
# Generated response: What is the mitosis?
#
# The mitosis is a process of the body's immune system reacting to a specific antigen. The immune system is able to recognize the antigen and recognize it as a specific antigen. The immune system can then recognize the antigen and recognize it as a specific antigen.
#
# The mitosis is a process of the body's immune system reacting to a specific antigen. The immune system is able to recognize the antigen and recognize it as a specific antigen. The mitosis is a process of the body's immune system reacting to a specific antigen.
#
# The mitosis is a process of the body's immune system reacting to a specific antigen.
#
# The mitosis is a process of the body's immune system reacting to
